# %% [markdown]
# ! git add .
# ! git commit -m "Archivos creados"
# ! git push

# %%
! git add .
! git commit -m "Parte 2 ejercicio 8 hecho"
! git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %% [markdown]
# Parte 1: Numpy:
# Para los ejercicios siguiente genere el código que considere
# para resolver el problema que se le plantea.
# 1) ¿Cuál es el tamaño en bytes de un array de 1000
# elementos de tipo booleano?

# %%
import numpy as np

# Creamos un array de booleanos con 1000 elementos
arr = np.random.choice([True, False], size=1000)

# Obtenemos el tamaño en bytes del array
size = arr.nbytes

print("El tamaño en bytes del array de 1000 elementos de tipo booleano es:", size)
# Out:
# El tamaño en bytes del array de 1000 elementos de tipo booleano es: 1000

# %% [markdown]
# 2) Cree un array cuyos elementos sean los enteros pares en
# [1,100] y en orden decreciente. Muestre los 10 últimos
# por pantalla.

# %%
import numpy as np
arr = np.arange(100, 0, -2)
ultimos10 = arr[-10:]
print(ultimos10)
# Out:
# [20 18 16 14 12 10  8  6  4  2]

# %% [markdown]
# 3) Dado el array
# 2 4 5 6
# 0 3 7 4
# 8 8 5 2
# 1 5 6 1
# Seleccione con una instrucción el subarray de elementos
# 0 3 7 4
# Después, seleccione el subarray de elementos
# 2 5
# 8 5

# %%
import numpy as np
arr = np.array([[2, 4, 5, 6],
                [0, 3, 7, 4],
                [8, 8, 5, 2],
                [1, 5, 6, 1]])
print(arr[1])
# Creamos una máscara booleana para los números 2, 5 y 8
print(arr[[0, 2], [0, 2]])
print(arr[[2, 2], [0, 2]])
# Out:
# [0 3 7 4]
# [2 5]
# [8 5]

# %% [markdown]
# 4) Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9],
# obtenga la media aritmética de la diferencia (a-b)

# %%
import numpy as np
arr = np.array([1, 4, 2, 7])
b = np.array([1, 3, 2, 9])
resta = arr-b
media = np.mean(resta)
resta
# Out:
# array([ 0,  1,  0, -2])

# %% [markdown]
# 5) Tengo valores de cordenadas (x, y) en las columnas
# del array
# 1.33 4.5
# 30.0 10.7
# 70.2 0.5
# Agregue a este array las coordenadas (37.1, -3.6).
# Muestre en pantalla las dimensiones del nuevo
# array

# %%
import numpy as np
arr = np.array([[1.33,4.5]
,[30.0,10.7]
,[70.2,0.5]])
print(arr)
arr1 = np.append(arr,[[37.1, -3.6]],axis = 0)
arr1
# Out:
# [[ 1.33  4.5 ]
#  [30.   10.7 ]
#  [70.2   0.5 ]]
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ],
#        [37.1 , -3.6 ]])

# %% [markdown]
# 6) Copie el array del ejercicio anterior. Traspóngalo (.
# Agregue ahora dos nuevos pares de coordenadas: (10.8,
# 3.0) y (35.8, 12.0).

# %%
import numpy as np

arr = np.array([[1.33,4.5]
,[30.0,10.7]
,[70.2,0.5]])
print(arr)
arrt = np.transpose(arr)
print(arrt)
nt = ([[10.8,3.0]
,[35.8,12.0]])
nt1 = np.transpose(nt)
nt1 = np.hstack((nt1, np.zeros((2, 1))))  # Agregar una columna de ceros
n = np.concatenate((arrt, nt1), axis=0)
print(n)
# Out:
# [[ 1.33  4.5 ]
#  [30.   10.7 ]
#  [70.2   0.5 ]]
# [[ 1.33 30.   70.2 ]
#  [ 4.5  10.7   0.5 ]]
# [[ 1.33 30.   70.2 ]
#  [ 4.5  10.7   0.5 ]
#  [10.8  35.8   0.  ]
#  [ 3.   12.    0.  ]]

# %% [markdown]
# Parte 2: Exploración y Minería de Datos:
# Con el dataset nucleospoblacion.csv adjunto al laboratorio,
# luego responda las siguientes preguntas usando pandas y
# matplotlib.

# %% [markdown]
# 1) ¿Cuántos Municipios tienen más de 100000
# habitantes?

# %%
import numpy as pd
import pandas as pd
arc = pd.read_csv("./NucleosPoblacion.csv")
df= pd.DataFrame(arc)
df_100k = df.loc[df['Poblacion'] > 100000]
print("Hay",df_100k,"municipios que tienen mas de 100000 habitantes")
# Out:
# Hay      FID  OBJECTID                       Texto  Poblacion  CodMun  \
# 9      9        10  Las Palmas de Gran Canaria   383308.0   35016
# 16    16        17                       Telde   100900.0   35026
# 28    28        29  San Cristóbal de La Laguna   152222.0   38023
# 40    40        41      Santa Cruz de Tenerife   222643.0   38038
# 42    42        43                     Badajoz   150376.0    6015
# ..   ...       ...                         ...        ...     ...
# 683  683       684    Santa Coloma de Gramenet   120060.0    8245
# 689  689       690                    Terrassa   212724.0    8279
# 725  725       726                      Lleida   137387.0   25120
# 735  735       736                        Reus   106622.0   43123
# 737  737       738                   Tarragona   140184.0   43148
#
#                       Municipio  CodProvin               Provincia          X  \
# 9    Las Palmas de Gran Canaria         35              Las Palmas -15.413387
# ...

# %% [markdown]
# 2) Realice una gráfica de barras sobre la polbación de cada
# ciudad, ordenela de menor a mayo y responda:
# a. ¿Cuál es la segunda ciudad más poblada?
# b. ¿Qué posición ocupa Granada en el ranking de
# las ciudades más pobladas?

# %%
import matplotlib.pyplot as plt

datos_ordenados = arc.sort_values(by='Poblacion')
plt.figure(figsize=(20, 20))
# Crear la gráfica de barras
plt.bar(datos_ordenados['Municipio'], datos_ordenados['Poblacion'])
plt.xticks(rotation=90)
plt.show()

# %%
df_sorted = df.sort_values(by=['Poblacion'], ascending=False)
second_city = df_sorted.iloc[1]['Provincia']
print("La segunda ciudad mas pobalda es",second_city)
# Out:
# La segunda ciudad mas pobalda es Barcelona

# %%
df_sorted = df.sort_values(by=['Poblacion'], ascending=False)
granada_row = df_sorted.loc[df_sorted['Provincia'] == 'Granada']
granada_rank = granada_row.index[0] + 1
print("La ciudad de Granada ocupa el puesto en el ranking:",granada_rank)
# Out:
# La ciudad de Granada ocupa el puesto en el ranking: 273

# %% [markdown]
# ¿Cuántos municipios de Extremadura tienen más de 5000
# habitantes?

# %%
extremadura_df = df.loc[df['Provincia'] == 'Extremadura']
num_municipios = len(extremadura_df.loc[extremadura_df['Poblacion'] > 50000])
print("La cantidad de municipios de Extremadura con mas de 50000 habitantos son:",num_municipios)
# Out:
# La cantidad de municipios de Extremadura con mas de 50000 habitantos son: 0

# %% [markdown]
# 4.¿Cuál es el municipio situado más al Norte? (Usar el
# valor de la coordenada "Y" que representa la latitud en
# grados). Proporcione también la provincia a la que
# pertenece y su población.

# %%
df_sorted = df.sort_values(by=['Y'], ascending=False)
municipio_norte = df_sorted.iloc[0]
print("La ciudad de Granada ocupa el puesto en el ranking:",municipio_norte)
# Out:
# La ciudad de Granada ocupa el puesto en el ranking: FID                104
# OBJECTID           105
# Texto          Viveiro
# Poblacion      16211.0
# CodMun           27066
# Municipio      Viveiro
# CodProvin           27
# Provincia         Lugo
# X            -7.588768
# Y            43.625578
# Name: 104, dtype: object

# %% [markdown]
# 5) Obtenga la media, mediana, desviación estándar, valor
# máximo y valor mínimo de la población de los municipios
# de la provincia de Granada

# %%
municipios_granada = df[df['Provincia'] == 'Granada']

# Obtener la media, mediana, desviación estándar, valor máximo y valor mínimo de la población
media = municipios_granada['Poblacion'].mean()
mediana = municipios_granada['Poblacion'].median()
desviacion_estandar = municipios_granada['Poblacion'].std()
valor_maximo = municipios_granada['Poblacion'].max()
valor_minimo = municipios_granada['Poblacion'].min()

# Mostrar los resultados
print('Media de población:', media)
print('Mediana de población:', mediana)
print('Desviación estándar de población:', desviacion_estandar)
print('Valor máximo de población:', valor_maximo)
print('Valor mínimo de población:', valor_minimo)
# Out:
# Media de población: 30217.85
# Mediana de población: 17526.0
# Desviación estándar de población: 50355.49171459276
# Valor máximo de población: 239154.0
# Valor mínimo de población: 10386.0

# %% [markdown]
# 6) Realice un histograma con la población de los
# Municipios para cada una de las provincias

# %%
import matplotlib.pyplot as plt
grupos_provincias = df.groupby('Provincia')
for nombre_provincia, grupo in grupos_provincias:
    plt.hist(grupo['Poblacion'], bins=10)
    plt.title('Histograma de Población para la provincia de ' + nombre_provincia)
    plt.xlabel('Población')
    plt.ylabel('Frecuencia')
    plt.show()

# %% [markdown]
# 7) Seleccione al azar cincuenta municipios diferentes de
# entre los diponibles en el archivo. Asegúrese de que no
# se repitan. ¿Luego calcule el promedio de la población y
# la desviación estándar de esto 50 municipios?

# %%
# Seleccionar al azar 50 municipios diferentes del DataFrame sin repeticiones
municipios_aleatorios = df.sample(n=50, replace=False)

# Calcular el promedio y la desviación estándar de la población de estos 50 municipios
promedio = municipios_aleatorios['Poblacion'].mean()
desviacion_estandar = municipios_aleatorios['Poblacion'].std()

# Mostrar los resultados
print('Promedio de población de los 50 municipios seleccionados al azar:', promedio)
print('Desviación estándar de población de los 50 municipios seleccionados al azar:', desviacion_estandar)
# Out:
# Promedio de población de los 50 municipios seleccionados al azar: 32695.92
# Desviación estándar de población de los 50 municipios seleccionados al azar: 47771.40183519416

# %% [markdown]
# 8) Dígame los nombres de los Municipios más cercano y más
# lejano a Madrid. Para ello debe calcular la distancia en
# todos ellos y Madrid. No considere a Madrid en el
# análisis ya que la distancia sería cero

# %%
import numpy as np
from math import radians, sin, cos, sqrt, atan2

# Obtener las coordenadas de Madrid en radianes
madrid_lat, madrid_lon = radians(40.4167754), radians(-3.7037902)

# Calcular la distancia entre Madrid y cada municipio
distancias = []
for i, row in df.iterrows():
    if row['Municipio'] == 'Madrid':
        continue
    municipio_lat, municipio_lon = radians(row['Y']), radians(row['X'])
    dlon = municipio_lon - madrid_lon
    dlat = municipio_lat - madrid_lat
    a = sin(dlat/2)**2 + cos(madrid_lat) * cos(municipio_lat) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distancia = 6371 * c # Radio de la tierra en km
    distancias.append((row['Municipio'], row['Provincia'], row['Poblacion'], distancia))

# Encontrar los municipios más cercanos y más lejanos
distancias = pd.DataFrame(distancias, columns=['Municipio', 'Provincia', 'Poblacion', 'Distancia'])
mas_cercano = distancias.loc[distancias['Distancia'].idxmin()]
mas_lejano = distancias.loc[distancias['Distancia'].idxmax()]

print("Municipio más cercano a Madrid:")
print(" - Nombre: ", mas_cercano['Municipio'])
print(" - Provincia: ", mas_cercano['Provincia'])
print(" - Población: ", mas_cercano['Poblacion'])
print(" - Distancia (km): ", round(mas_cercano['Distancia'], 2))

print("Municipio más lejano a Madrid:")
print(" - Nombre: ", mas_lejano['Municipio'])
print(" - Provincia: ", mas_lejano['Provincia'])
print(" - Población: ", mas_lejano['Poblacion'])
print(" - Distancia (km): ", round(mas_lejano['Distancia'], 2))
# Out:
# Municipio más cercano a Madrid:
#  - Nombre:  Pozuelo de Alarcón
#  - Provincia:  Madrid
#  - Población:  14800.0
#  - Distancia (km):  6.91
# Municipio más lejano a Madrid:
#  - Nombre:  Los Llanos de Aridane
#  - Provincia:  Santa Cruz de Tenerife
#  - Población:  20948.0
#  - Distancia (km):  1840.23
